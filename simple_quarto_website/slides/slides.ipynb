# %% [markdown]
# ---
# title: "Lab"
# author: "Mandalika Sai Prerana"
# format: revealjs
# bibliography: ../reference.bib
# ---
#
# # In the morning
# ## First slide
#
# - Turn off alarm
# - Get out of bed
#
# ## second slide
#
# ![Georgeotown1](images/georgetown1.png)
# ![Georgetown2](images/georgetown2.jpeg)
#
# ## third slide
#
# <p>Below are two citations from bib file</p>
#
# [@smith2010]
# [@einstein1905theory]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate x values from 0 to 2*pi
x = np.linspace(0, 2 * np.pi, 100)  # 100 points between 0 and 2*pi
# Compute corresponding y values (sine wave)
y = np.sin(x)

# Create a figure and axis
fig, ax = plt.subplots()

# Plot the sine wave
ax.plot(x, y, label='Sine Wave', color='blue', linestyle='-')

# Add labels and title
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_title('Sine Wave Plot')

# Add a legend
ax.legend()

# Display the plot
plt.show()
